# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('furniture.csv',encoding ='latin-1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
# ...

# %%
df.isna().sum()
# Out:
# Row ID              0
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Unnamed: 16      9994
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Inventory           0
# dtype: int64

# %%
df.drop(['Unnamed: 16','Product ID','Customer ID','Order ID','Row ID'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'Country', 'City', 'State', 'Postal Code', 'Region', 'Category',
#        'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit', 'Inventory'],
#       dtype='object')

# %%
encoder = LabelEncoder()
encoder.fit(df['Ship Mode'])
df['Ship Mode'] = encoder.transform(df['Ship Mode'])
encoder.classes_
# Out:
# array(['First Class', 'Same Day', 'Second Class', 'Standard Class'],
#       dtype=object)

# %%
encoder = LabelEncoder()
encoder.fit(df['Customer Name'])
df['Customer Name'] = encoder.transform(df['Customer Name'])
encoder.classes_
# Out:
# array(['Aaron Bergman', 'Aaron Hawkins', 'Aaron Smayling',
#        'Adam Bellavance', 'Adam Hart', 'Adam Shillingsburg',
#        'Adrian Barton', 'Adrian Hane', 'Adrian Shami', 'Aimee Bixby',
#        'Alan Barnes', 'Alan Dominguez', 'Alan Haines', 'Alan Hwang',
#        'Alan Schoenberger', 'Alan Shonely', 'Alejandro Ballentine',
#        'Alejandro Grove', 'Alejandro Savely', 'Aleksandra Gannaway',
#        'Alex Avila', 'Alex Grayson', 'Alex Russell', 'Alice McCarthy',
#        'Allen Armold', 'Allen Goldenen', 'Allen Rosenblatt',
#        'Alyssa Crouse', 'Alyssa Tate', 'Amy Cox', 'Amy Hunt',
#        'Andrew Allen', 'Andrew Gjertsen', 'Andrew Roberts',
#        'Andy Gerbode', 'Andy Reiter', 'Andy Yotov', 'Anemone Ratner',
#        'Angele Hood', 'Ann Blume', 'Ann Chong', 'Ann Steele',
#        'Anna Andreadi', 'Anna Chung', 'Anna Gayman', 'Anna Hï¿½berlin',
#        'Anne McFarland', 'Anne Pryor', 'Annie Thurman', 'Annie Zypern',
# ...

# %%
encoder = LabelEncoder()
encoder.fit(df['State'])
df['State'] = encoder.transform(df['State'])
encoder.classes_
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida',
#        'Georgia', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
encoder = LabelEncoder()
encoder.fit(df['Country'])
df['Country'] = encoder.transform(df['Country'])
encoder.classes_
# Out:
# array(['United States'], dtype=object)

# %%
encoder = LabelEncoder()
encoder.fit(df['Category'])
df['Category'] = encoder.transform(df['Category'])
encoder.classes_
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
encoder = LabelEncoder()
encoder.fit(df['Region'])
df['Region'] = encoder.transform(df['Region'])
encoder.classes_
# Out:
# array(['Central', 'East', 'South', 'West'], dtype=object)

# %%
df
# Out:
#       Order Date   Ship Date  Ship Mode  Customer Name    Segment  Country  \
# 0      11/8/2016  11/11/2016          2            166   Consumer        0
# 1      11/8/2016  11/11/2016          2            166   Consumer        0
# 2      6/12/2016   6/16/2016          2            201  Corporate        0
# 3     10/11/2015  10/18/2015          3            687   Consumer        0
# 4     10/11/2015  10/18/2015          3            687   Consumer        0
# ...          ...         ...        ...            ...        ...      ...
# 9989   1/21/2014   1/23/2014          2            758   Consumer        0
# 9990   2/26/2017    3/3/2017          3            202   Consumer        0
# 9991   2/26/2017    3/3/2017          3            202   Consumer        0
# 9992   2/26/2017    3/3/2017          3            202   Consumer        0
# 9993    5/4/2017    5/9/2017          2            146   Consumer        0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9994 non-null   object
#  1   Ship Date      9994 non-null   object
#  2   Ship Mode      9994 non-null   int64
#  3   Customer Name  9994 non-null   int64
#  4   Segment        9994 non-null   object
#  5   Country        9994 non-null   int64
#  6   City           9994 non-null   object
#  7   State          9994 non-null   int64
#  8   Postal Code    9994 non-null   int64
#  9   Region         9994 non-null   int64
#  10  Category       9994 non-null   int64
#  11  Sub-Category   9994 non-null   object
#  12  Sales          9994 non-null   object
#  13  Quantity       9994 non-null   float64
#  14  Discount       9994 non-null   float64
#  15  Profit         9994 non-null   float64
#  16  Inventory      9994 non-null   object
# ...

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['date_difference'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df.drop(['Order Date','Ship Date'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Inventory', 'date_difference'],
#       dtype='object')

# %%
df.head()
# Out:
#    Ship Mode  Customer Name    Segment  Country             City  State  \
# 0          2            166   Consumer        0        Henderson     15
# 1          2            166   Consumer        0        Henderson     15
# 2          2            201  Corporate        0      Los Angeles      3
# 3          3            687   Consumer        0  Fort Lauderdale      8
# 4          3            687   Consumer        0  Fort Lauderdale      8
#
#    Postal Code  Region  Category Sub-Category     Sales  Quantity  Discount  \
# 0        42420       2         0    Bookcases    261.96       2.0      0.00
# 1        42420       2         0       Chairs    731.94       3.0      0.00
# 2        90036       3         1       Labels     14.62       2.0      0.00
# 3        33311       2         0       Tables  957.5775       5.0      0.45
# 4        33311       2         1      Storage    22.368       2.0      0.20
#
#      Profit  Inventory  date_difference
# ...

# %%
encoder = LabelEncoder()
encoder.fit(df['Sub-Category'])
df['Sub-Category'] = encoder.transform(df['Sub-Category'])
encoder.classes_
# Out:
# array(['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases',
#        'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings',
#        'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies',
#        'Tables'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ship Mode        9994 non-null   int64
#  1   Customer Name    9994 non-null   int64
#  2   Segment          9994 non-null   object
#  3   Country          9994 non-null   int64
#  4   City             9994 non-null   object
#  5   State            9994 non-null   int64
#  6   Postal Code      9994 non-null   int64
#  7   Region           9994 non-null   int64
#  8   Category         9994 non-null   int64
#  9   Sub-Category     9994 non-null   int64
#  10  Sales            9994 non-null   object
#  11  Quantity         9994 non-null   float64
#  12  Discount         9994 non-null   float64
#  13  Profit           9994 non-null   float64
#  14  Inventory        9994 non-null   object
#  15  date_difference  9994 non-null   int64
# dtypes: float64(3), int64(9), object(4)
# ...

# %%
df1=pd.to_numeric(df['Sales'],errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9994 entries, 0 to 9993
# Series name: Sales
# Non-Null Count  Dtype
# --------------  -----
# 9988 non-null   float64
# dtypes: float64(1)
# memory usage: 78.2 KB

# %%
frames = [df,df1]

# %%
result_data =pd.concat(frames, axis=1,names=['sales'])

# %%
result_data.info()
result_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ship Mode        9994 non-null   int64
#  1   Customer Name    9994 non-null   int64
#  2   Segment          9994 non-null   object
#  3   Country          9994 non-null   int64
#  4   City             9994 non-null   object
#  5   State            9994 non-null   int64
#  6   Postal Code      9994 non-null   int64
#  7   Region           9994 non-null   int64
#  8   Category         9994 non-null   int64
#  9   Sub-Category     9994 non-null   int64
#  10  Sales            9994 non-null   object
#  11  Quantity         9994 non-null   float64
#  12  Discount         9994 non-null   float64
#  13  Profit           9994 non-null   float64
#  14  Inventory        9994 non-null   object
#  15  date_difference  9994 non-null   int64
#  16  Sales            9988 non-null   float64
# ...

# %%
# result_data.to_csv("final.csv")
# result_data
df = pd.read_csv('final.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9994 non-null   int64
#  1   Ship Mode        9994 non-null   int64
#  2   Customer Name    9994 non-null   int64
#  3   Segment          9994 non-null   int64
#  4   Country          9994 non-null   int64
#  5   City             9994 non-null   int64
#  6   State            9994 non-null   int64
#  7   Postal Code      9994 non-null   int64
#  8   Region           9994 non-null   int64
#  9   Category         9994 non-null   int64
#  10  Sub-Category     9994 non-null   int64
#  11  Sales            9994 non-null   object
#  12  Quantity         9994 non-null   float64
#  13  Discount         9994 non-null   float64
#  14  Profit           9994 non-null   float64
#  15  Inventory        9994 non-null   object
#  16  date_difference  9994 non-null   int64
# ...

# %%
df2=pd.to_numeric(df['Inventory'],errors='coerce')

# %%
df2.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9994 entries, 0 to 9993
# Series name: Inventory
# Non-Null Count  Dtype
# --------------  -----
# 9988 non-null   float64
# dtypes: float64(1)
# memory usage: 78.2 KB

# %%
frames2 = [df,df2]

# %%
Final_data=pd.concat(frames2, axis=1,names=['Inventry'])

# %%
Final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9994 non-null   int64
#  1   Ship Mode        9994 non-null   int64
#  2   Customer Name    9994 non-null   int64
#  3   Segment          9994 non-null   int64
#  4   Country          9994 non-null   int64
#  5   City             9994 non-null   int64
#  6   State            9994 non-null   int64
#  7   Postal Code      9994 non-null   int64
#  8   Region           9994 non-null   int64
#  9   Category         9994 non-null   int64
#  10  Sub-Category     9994 non-null   int64
#  11  Sales            9994 non-null   object
#  12  Quantity         9994 non-null   float64
#  13  Discount         9994 non-null   float64
#  14  Profit           9994 non-null   float64
#  15  Inventory        9994 non-null   object
#  16  date_difference  9994 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1       11
# Unnamed: 0          9
# Ship Mode           0
# Customer Name      16
# Segment             7
# Country             2
# City                5
# State               0
# Postal Code        29
# Region              9
# Category            3
# Sub-Category        9
# Quantity            6
# Discount            5
# Profit             23
# date_difference    14
# Sales.1            15
# Inventory          21
# dtype: int64

# %%
# Final_data.to_csv("final1_New.csv")
# Final_data
df = pd.read_csv('final1_New.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0.1     9983 non-null   float64
#  1   Unnamed: 0       9985 non-null   float64
#  2   Ship Mode        9994 non-null   int64
#  3   Customer Name    9978 non-null   float64
#  4   Segment          9987 non-null   float64
#  5   Country          9992 non-null   float64
#  6   City             9989 non-null   float64
#  7   State            9994 non-null   int64
#  8   Postal Code      9965 non-null   float64
#  9   Region           9985 non-null   float64
#  10  Category         9991 non-null   float64
#  11  Sub-Category     9985 non-null   float64
#  12  Quantity         9988 non-null   float64
#  13  Discount         9989 non-null   float64
#  14  Profit           9971 non-null   float64
#  15  date_difference  9980 non-null   float64
# ...

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  Ship Mode  Customer Name  Segment  Country  \
# 0              0.0         0.0          2          166.0      0.0      0.0
# 1              1.0         1.0          2          166.0      0.0      0.0
# 2              2.0         2.0          2          201.0      1.0      0.0
# 3              3.0         3.0          3          687.0      0.0      0.0
# 4              4.0         4.0          3          687.0      0.0      0.0
# ...            ...         ...        ...            ...      ...      ...
# 9989        9989.0      9989.0          2          758.0      0.0      0.0
# 9990        9990.0      9990.0          3          202.0      0.0      0.0
# 9991        9991.0      9991.0          3          202.0      0.0      0.0
# 9992        9992.0      9992.0          3          202.0      0.0      0.0
# 9993        9993.0      9993.0          2          146.0      0.0      0.0
#
# ...

# %%
df.drop(['Unnamed: 0.1','Unnamed: 0','Sales','Inventory'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_22516/2992290404.py in <module>
# ----> 1 df.drop(['Unnamed: 0.1','Unnamed: 0','Sales','Inventory'],axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5345                 weight  1.0     0.8
#    5346         """
# -> 5347         return super().drop(
#    5348             labels=labels,
#    5349             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1       11
# Unnamed: 0          9
# Ship Mode           0
# Customer Name      16
# Segment             7
# Country             2
# City                5
# State               0
# Postal Code        29
# Region              9
# Category            3
# Sub-Category        9
# Quantity            6
# Discount            5
# Profit             23
# date_difference    14
# Sales.1            15
# Inventory          21
# dtype: int64

# %%
# from miceforest import ImputationKernel
# mice_obj = ImputationKernel(
#     data=df.drop(['Unnamed: 0.1 ','Unnamed: 0'],axis=1,inplace=True),
#     random_state=12345
# )
# mice_obj.mice(5)
# df1=mice_obj.complete_data()
Sales = df['Sales.1'].mean()
df['Sales.1'].fillna(Sales,inplace=True)

# %%
Sales = df['Inventory'].mean()
df['Inventory'].fillna(Sales,inplace=True)

# %%
df.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)

# %%
Sales = df['date_difference'].mean()
df['date_difference'].fillna(Sales,inplace=True)

# %%
Sales = df['Profit'].mean()
df['Profit'].fillna(Sales,inplace=True)

# %%
Sales = df['Discount'].mean()
df['Discount'].fillna(Sales,inplace=True)

# %%
Sales = df['Quantity'].mean()
df['Quantity'].fillna(Sales,inplace=True)

# %%
df['Ship Mode'].fillna(method='ffill',inplace=True)
df['Customer Name'].fillna(method='ffill',inplace=True)
df['Segment'].fillna(method='ffill',inplace=True)
df['Country'].fillna(method='ffill',inplace=True)
df['State'].fillna(method='ffill',inplace=True)
df['City'].fillna(method='ffill',inplace=True)
df['Category'].fillna(method='ffill',inplace=True)
df['Sub-Category'].fillna(method='ffill',inplace=True)
df['State'].fillna(method='ffill',inplace=True)
df['City'].fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_22516/1690329379.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Ship Mode'].fillna(method='ffill',inplace=True)
# /tmp/ipykernel_22516/1690329379.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Customer Name'].fillna(method='ffill',inplace=True)
# /tmp/ipykernel_22516/1690329379.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Segment'].fillna(method='ffill',inplace=True)
# /tmp/ipykernel_22516/1690329379.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Country'].fillna(method='ffill',inplace=True)
# ...

# %%
df.isna().sum()
# Out:
# Ship Mode           0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code        29
# Region              9
# Category            0
# Sub-Category        0
# Quantity            0
# Discount            0
# Profit              0
# date_difference     0
# Sales.1             0
# Inventory           0
# dtype: int64

# %%
df['Region'].fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_22516/716042145.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Region'].fillna(method='ffill',inplace=True)

# %%
Sales = df['Postal Code'].mean()
df['Postal Code'].fillna(Sales,inplace=True)

# %%
df['Region'].fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_22516/716042145.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Region'].fillna(method='ffill',inplace=True)

# %%
df.isna().sum()
# Out:
# Ship Mode          0
# Customer Name      0
# Segment            0
# Country            0
# City               0
# State              0
# Postal Code        0
# Region             0
# Category           0
# Sub-Category       0
# Quantity           0
# Discount           0
# Profit             0
# date_difference    0
# Sales.1            0
# Inventory          0
# dtype: int64
